# %% [markdown]
# ***
# # Setup
# ***

# %%
# !pip install -r requirements.txt

import logging
#logger = logging.getLogger()
#logger.setLevel(logging.INFO)

import pandas as pd
import requests
import zipfile
import os
import shutil
from SPARQLWrapper import SPARQLWrapper, JSON, XML
import logging

from data_imports import *
# Out:
# Requirement already satisfied: SPARQLWrapper==1.8.4 in /srv/paws/lib/python3.6/site-packages (from -r requirements.txt (line 1))
# Requirement already satisfied: rdflib>=4.0 in /srv/paws/lib/python3.6/site-packages (from SPARQLWrapper==1.8.4->-r requirements.txt (line 1))
# Requirement already satisfied: isodate in /srv/paws/lib/python3.6/site-packages (from rdflib>=4.0->SPARQLWrapper==1.8.4->-r requirements.txt (line 1))
# Requirement already satisfied: pyparsing in /srv/paws/lib/python3.6/site-packages (from rdflib>=4.0->SPARQLWrapper==1.8.4->-r requirements.txt (line 1))
# Requirement already satisfied: six in /srv/paws/lib/python3.6/site-packages (from isodate->rdflib>=4.0->SPARQLWrapper==1.8.4->-r requirements.txt (line 1))

# %% [markdown]
# ***
# # Import Data
# ***

# %%
df_api = import_kantonZH_api() 
df_wikidata = import_wikidata_kantonZH()
swisstopowikidata = import_swisstopowikidata_kantonZH()

# %%
print(df_api.shape)
df_api.head()
# Out:
# (10032, 4)
#    BFS_NR     GEBIET_NAME        date  population
# 0      21         Adlikon  2018-12-31       707.0
# 1     131        Adliswil  2018-12-31     18681.0
# 2     241        Aesch ZH  2018-12-31      1555.0
# 3       1     Aeugst a.A.  2018-12-31      1979.0
# 4       2  Affoltern a.A.  2018-12-31     12201.0

# %%
print(df_wikidata.shape)
df_wikidata.head()
# Out:
# (815, 7)
#    bfs_id        date population      qualifier  \
# 0       1  2017-01-01       1934     NormalRank
# 1       1  2017-12-31       1941     NormalRank
# 2       1  2018-12-31       1982     NormalRank
# 3       2  2012-12-31      11276     NormalRank
# 4       2  2017-01-01      12080  PreferredRank
#
#                              refpublisher  \
# 0                                      NA
# 1  http://www.wikidata.org/entity/Q285453
# 2  http://www.wikidata.org/entity/Q285453
# 3                                      NA
# 4                                      NA
#
#                                               refurl wikidata_id
# 0  https://statistik.zh.ch/internet/justiz_innere...      Q64945
# 1  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...      Q64945
# 2  https://www.bfs.admin.ch/bfs/de/home/statistik...      Q64945
# 3  http://www.pxweb.bfs.admin.ch/Dialog/varval.as...      Q68290
# 4  https://statistik.zh.ch/internet/justiz_innere...      Q68290

# %%
print(swisstopowikidata.shape)
swisstopowikidata.head()
# Out:
# (162, 3)
#         Name  bfs wikidata_id
# 0     Stadel  100      Q67907
# 1   Obfelden   10      Q65942
# 2  Rüti (ZH)  118      Q69752
# 3  Seegräben  119      Q67310
# 4  Ottenbach   11      Q67513

# %% [markdown]
# ***
#
# # Merge df_api with swisstopowikidata
#
# Aim: add wikidata qnumber to df_api
#
# Observation: Not all bfsnumbers can be linked to a qnumber. Reason: "Gemeindefusionen"
#
# Decision: Only use bfsnumbers that are active today.
# ***

# %%
df_api_qnumber = pd.merge(df_api, swisstopowikidata, how='left', left_on=['BFS_NR'], right_on=['bfs'])
print(df_api_qnumber.shape)
df_api_qnumber.head()
# Out:
# (10032, 7)
#    BFS_NR     GEBIET_NAME        date  population                Name    bfs  \
# 0      21         Adlikon  2018-12-31       707.0             Adlikon   21.0
# 1     131        Adliswil  2018-12-31     18681.0            Adliswil  131.0
# 2     241        Aesch ZH  2018-12-31      1555.0          Aesch (ZH)  241.0
# 3       1     Aeugst a.A.  2018-12-31      1979.0     Aeugst am Albis    1.0
# 4       2  Affoltern a.A.  2018-12-31     12201.0  Affoltern am Albis    2.0
#
#   wikidata_id
# 0      Q68356
# 1      Q68210
# 2      Q68342
# 3      Q64945
# 4      Q68290

# %%
# view na in kantonZHapiANDswisstopowikidata
df_api_qnumber_na = df_api_qnumber[df_api_qnumber.isna().any(axis=1)].sort_values(by=['BFS_NR'])
print(df_api_qnumber_na.shape)
print(df_api_qnumber_na.BFS_NR.unique()) # !!! Warum sind für diese keine Q Wikinr. vorhanden?)
df_api_qnumber_na
# Out:
# (798, 7)
# [ 36  42  44 132 133 134 140 142 171 174 175 179 217 222]
#       BFS_NR               GEBIET_NAME        date  population Name  bfs  \
# 8024      36  Oberstammheim (bis 2018)  1973-12-31       760.0  NaN  NaN
# 1160      36  Oberstammheim (bis 2018)  2012-12-31      1125.0  NaN  NaN
# 3624      36  Oberstammheim (bis 2018)  1998-12-31      1041.0  NaN  NaN
# 9256      36  Oberstammheim (bis 2018)  1966-12-31       850.0  NaN  NaN
# 7496      36  Oberstammheim (bis 2018)  1976-12-31       785.0  NaN  NaN
# 3800      36  Oberstammheim (bis 2018)  1997-12-31      1042.0  NaN  NaN
# 984       36  Oberstammheim (bis 2018)  2013-12-31      1142.0  NaN  NaN
# 7320      36  Oberstammheim (bis 2018)  1977-12-31       788.0  NaN  NaN
# 4152      36  Oberstammheim (bis 2018)  1995-12-31      1069.0  NaN  NaN
# 9432      36  Oberstammheim (bis 2018)  1965-12-31       831.0  NaN  NaN
# 7144      36  Oberstammheim (bis 2018)  1978-12-31       794.0  NaN  NaN
# 808       36  Oberstammheim (bis 2018)  2014-12-31      1154.0  NaN  NaN
# 4328      36  Oberstammheim (bis 2018)  1994-12-31      1053.0  NaN  NaN
# 4504      36  Oberstammheim (bis 2018)  1993-12-31      1041.0  NaN  NaN
# 6968      36  Oberstammheim (bis 2018)  1979-12-31       822.0  NaN  NaN
# 4680      36  Oberstammheim (bis 2018)  1992-12-31      1037.0  NaN  NaN
# 632       36  Oberstammheim (bis 2018)  2015-12-31      1173.0  NaN  NaN
# 9608      36  Oberstammheim (bis 2018)  1964-12-31       834.0  NaN  NaN
# 7672      36  Oberstammheim (bis 2018)  1975-12-31       775.0  NaN  NaN
# 6792      36  Oberstammheim (bis 2018)  1980-12-31       842.0  NaN  NaN
# 3448      36  Oberstammheim (bis 2018)  1999-12-31      1048.0  NaN  NaN
# 7848      36  Oberstammheim (bis 2018)  1974-12-31       746.0  NaN  NaN
# 6049     222     Hofstetten (bis 2017)  1984-12-31       372.0  NaN  NaN
#
#      wikidata_id
# 8024         NaN
# 1160         NaN
# 3624         NaN
# 9256         NaN
# 7496         NaN
# 3800         NaN
# 984          NaN
# 7320         NaN
# 4152         NaN
# 9432         NaN
# 7144         NaN
# 808          NaN
# 4328         NaN
# 4504         NaN
# 6968         NaN
# 4680         NaN
# 632          NaN
# 9608         NaN
# 7672         NaN
# 6792         NaN
# 3448         NaN
# 7848         NaN
# 8728         NaN
# 2040         NaN
# 1864         NaN
# 8552         NaN
# 2216         NaN
# 2392         NaN
# 1688         NaN
# 8904         NaN
# ...          ...
# 8689         NaN
# 5345         NaN
# 8337         NaN
# 2177         NaN
# 2529         NaN
# 8513         NaN
# 2353         NaN
# 3761         NaN
# 5169         NaN
# 769          NaN
# 1649         NaN
# 9041         NaN
# 7985         NaN
# 3057         NaN
# 4641         NaN
# 5697         NaN
# 945          NaN
# 9393         NaN
# 3585         NaN
# 8161         NaN
# 6929         NaN
# 7281         NaN
# 9217         NaN
# 7633         NaN
# 1297         NaN
# 2881         NaN
# 5521         NaN
# 1473         NaN
# 1121         NaN
# 6049         NaN
#
# [798 rows x 7 columns]

# %%
df_api_qnumber[df_api_qnumber['BFS_NR']==297]
# Out:
#       BFS_NR GEBIET_NAME        date  population   Name    bfs wikidata_id
# 11       297       Bauma  2018-12-31      4961.0  Bauma  297.0      Q67145
# 187      297       Bauma  2017-12-31      4925.0  Bauma  297.0      Q67145
# 363      297       Bauma  2016-12-31      4896.0  Bauma  297.0      Q67145
# 539      297       Bauma  2015-12-31      4837.0  Bauma  297.0      Q67145
# 715      297       Bauma  2014-12-31      4718.0  Bauma  297.0      Q67145
# 891      297       Bauma  2013-12-31      4650.0  Bauma  297.0      Q67145
# 1067     297       Bauma  2012-12-31      4569.0  Bauma  297.0      Q67145
# 1243     297       Bauma  2011-12-31      4550.0  Bauma  297.0      Q67145
# 1419     297       Bauma  2010-12-31      4522.0  Bauma  297.0      Q67145
# 1595     297       Bauma  2009-12-31      4516.0  Bauma  297.0      Q67145
# 1771     297       Bauma  2008-12-31      4523.0  Bauma  297.0      Q67145
# 1947     297       Bauma  2007-12-31      4544.0  Bauma  297.0      Q67145
# 2123     297       Bauma  2006-12-31      4549.0  Bauma  297.0      Q67145
# 2299     297       Bauma  2005-12-31      4469.0  Bauma  297.0      Q67145
# 2475     297       Bauma  2004-12-31      4555.0  Bauma  297.0      Q67145
# 2651     297       Bauma  2003-12-31      4579.0  Bauma  297.0      Q67145
# 2827     297       Bauma  2002-12-31      4582.0  Bauma  297.0      Q67145
# 3003     297       Bauma  2001-12-31      4521.0  Bauma  297.0      Q67145
# 3179     297       Bauma  2000-12-31      4520.0  Bauma  297.0      Q67145
# 3355     297       Bauma  1999-12-31      4538.0  Bauma  297.0      Q67145
# 3531     297       Bauma  1998-12-31      4585.0  Bauma  297.0      Q67145
# 3707     297       Bauma  1997-12-31      4663.0  Bauma  297.0      Q67145
# 9468     179  Sternenberg (bis 2014)  1965-12-31       381.0  NaN  NaN
# 9644     179  Sternenberg (bis 2014)  1964-12-31       392.0  NaN  NaN
# 9820     179  Sternenberg (bis 2014)  1963-12-31       388.0  NaN  NaN
# 9996     179  Sternenberg (bis 2014)  1962-12-31       391.0  NaN  NaN
#
#      wikidata_id
# 140          NaN
# 316          NaN
# 492          NaN
# 668          NaN
# 844          NaN
# 1020         NaN
# 1196         NaN
# 1372         NaN
# 1548         NaN
# 1724         NaN
# 1900         NaN
# 2076         NaN
# 2252         NaN
# 2428         NaN
# 2604         NaN
# 2780         NaN
# 2956         NaN
# 3132         NaN
# 3308         NaN
# 3484         NaN
# 3660         NaN
# 3836         NaN
# 4012         NaN
# 4188         NaN
# 4364         NaN
# 4540         NaN
# 4716         NaN
# 4892         NaN
# 5068         NaN
# 5244         NaN
# 5420         NaN
# 5596         NaN
# 5772         NaN
# 5948         NaN
# 6124         NaN
# 6300         NaN
# 6476         NaN
# 6652         NaN
# 6828         NaN
# 7004         NaN
# 7180         NaN
# 7356         NaN
# 7532         NaN
# 7708         NaN
# 7884         NaN
# 8060         NaN
# 8236         NaN
# 8412         NaN
# 8588         NaN
# 8764         NaN
# 8940         NaN
# 9116         NaN
# 9292         NaN
# 9468         NaN
# 9644         NaN
# 9820         NaN
# 9996         NaN

# %%
df_api_qnumber_dropna = pd.merge(df_api, swisstopowikidata, how='left', left_on=['BFS_NR'], right_on=['bfs']).dropna()
print(df_api_qnumber_dropna.shape)
df_api_qnumber_dropna.head()
# Out:
# (9234, 7)
#    BFS_NR     GEBIET_NAME        date  population                Name    bfs  \
# 0      21         Adlikon  2018-12-31       707.0             Adlikon   21.0
# 1     131        Adliswil  2018-12-31     18681.0            Adliswil  131.0
# 2     241        Aesch ZH  2018-12-31      1555.0          Aesch (ZH)  241.0
# 3       1     Aeugst a.A.  2018-12-31      1979.0     Aeugst am Albis    1.0
# 4       2  Affoltern a.A.  2018-12-31     12201.0  Affoltern am Albis    2.0
#
#   wikidata_id
# 0      Q68356
# 1      Q68210
# 2      Q68342
# 3      Q64945
# 4      Q68290

# %%
# check
if df_api_qnumber_na.shape[0] + df_api_qnumber_dropna.shape[0] == df_api_qnumber.shape[0]:
    print("check ok")
# Out:
# check ok

# %% [markdown]
# ***
# # Merge df_api with wikidata TODO !!!! MESSY !!!
#
#
# Aim: Check population and ... ???
#
# ***

# %%
df_api_qnumber_dropna['check'] = df_api_qnumber_dropna['date'].astype(str) + '---' + df_api['BFS_NR'].astype(str)
df_wikidata['check'] = df_wikidata['date'].astype(str) + '---' + df_wikidata['bfs_id'].astype(str)

# %%
df_api_sel_f = df_api_qnumber_dropna[(df_api_qnumber_dropna['check'].isin(df_wikidata['check']) == False)]
df_api_sel_f.to_csv("test.tsv", header = True, sep='\t')
print(df_api_sel_f.columns)
print(df_api_sel_f.shape)
df_api_sel_f.head()
# Out:
# Index(['BFS_NR', 'GEBIET_NAME', 'date', 'population', 'Name', 'bfs',
#        'wikidata_id', 'check'],
#       dtype='object')
# (8871, 8)
#      BFS_NR GEBIET_NAME        date  population       Name    bfs wikidata_id  \
# 138     292   Stammheim  2018-12-31      2740.0  Stammheim  292.0   Q60322693
# 213     294        Elgg  2017-12-31      4903.0       Elgg  294.0      Q67137
# 314     292   Stammheim  2017-12-31      2741.0  Stammheim  292.0   Q60322693
# 352      21     Adlikon  2016-12-31       662.0    Adlikon   21.0      Q68356
# 353     131    Adliswil  2016-12-31     18651.0   Adliswil  131.0      Q68210
#
#                 check
# 138  2018-12-31---292
# 213  2017-12-31---294
# 314  2017-12-31---292
# 352   2016-12-31---21
# 353  2016-12-31---131

# %%
df_api_sel_t = df_api_qnumber_dropna[(df_api_qnumber_dropna['check'].isin(df_wikidata['check']) == True)]
print(df_api_sel_t.columns)
print(df_api_sel_t.shape)
df_api_sel_t.head()
# Out:
# Index(['BFS_NR', 'GEBIET_NAME', 'date', 'population', 'Name', 'bfs',
#        'wikidata_id', 'check'],
#       dtype='object')
# (363, 8)
#    BFS_NR     GEBIET_NAME        date  population                Name    bfs  \
# 0      21         Adlikon  2018-12-31       707.0             Adlikon   21.0
# 1     131        Adliswil  2018-12-31     18681.0            Adliswil  131.0
# 2     241        Aesch ZH  2018-12-31      1555.0          Aesch (ZH)  241.0
# 3       1     Aeugst a.A.  2018-12-31      1979.0     Aeugst am Albis    1.0
# 4       2  Affoltern a.A.  2018-12-31     12201.0  Affoltern am Albis    2.0
#
#   wikidata_id             check
# 0      Q68356   2018-12-31---21
# 1      Q68210  2018-12-31---131
# 2      Q68342  2018-12-31---241
# 3      Q64945    2018-12-31---1
# 4      Q68290    2018-12-31---2

# %%
df_api_wikidata = pd.merge(df_api_sel_t, df_wikidata, how='left', left_on=['check'], right_on=['check'])
# df_api instead of df_api_sel_t ???
print(df_api_wikidata.columns)
print(df_api_wikidata.shape)
print(df_api_wikidata.shape)
df_api_wikidata[["Name", "BFS_NR", "wikidata_id_y", "date_x", "date_y", "population_x", "population_y", "refurl"]].sort_values(by=['BFS_NR'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-16e79dace8b4> in <module>
# ----> 1 df_api_wikidata = pd.merge(df_api, df_wikidata, how='left', left_on=['check'], right_on=['check'])
#       2 #print(df_api_wikidata.columns)
#       3 #print(df_api_wikidata.shape)
#       4 #print(df_api_wikidata.shape)
#       5 #df_api_wikidata[["Name", "BFS_NR", "wikidata_id_y", "date_x", "date_y", "population_x", "population_y", "refurl"]].sort_values(by=['BFS_NR'])
#
# /srv/paws/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# /srv/paws/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# /srv/paws/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     844                         right_keys.append(rk)
#     845                     if lk is not None:
# --> 846                         left_keys.append(left._get_label_or_level_values(lk))
#     847                         join_names.append(lk)
#     848                     else:
#
# /srv/paws/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    
# 49    57.0        Q66964   2018-12-31---57      57  2018-12-31         2371
# 48    57.0        Q66964   2018-12-31---57      57  2018-12-31         2371
# 71    87.0        Q65671   2018-12-31---87      87  2018-12-31          925
# 70    87.0        Q65671   2018-12-31---87      87  2018-12-31          925
# 102   93.0        Q70264   2018-12-31---93      93  2018-12-31         1802
#
#          qualifier                            refpublisher  \
# 326  PreferredRank                                      NA
# 325     NormalRank  http://www.wikidata.org/entity/Q285453
# 290     NormalRank  http://www.wikidata.org/entity/Q285453
# 336     NormalRank  http://www.wikidata.org/entity/Q285453
# 311     NormalRank  http://www.wikidata.org/entity/Q285453
# 233     NormalRank                                      NA
# 236     NormalRank                                      NA
# 237     NormalRank                                      NA
# 322     NormalRank  http://www.wikidata.org/entity/Q285453
# 323     NormalRank                                      NA
# 334     NormalRank  http://www.wikidata.org/entity/Q285453
# 333     NormalRank                                      NA
# 269     NormalRank  http://www.wikidata.org/entity/Q285453
# 294     NormalRank  http://www.wikidata.org/entity/Q285453
# 123     NormalRank  http://www.wikidata.org/entity/Q285453
# 92      NormalRank                                      NA
# 141  PreferredRank                                      NA
# 140  PreferredRank  http://www.wikidata.org/entity/Q285453
# 49      NormalRank                                      NA
# 48      NormalRank  http://www.wikidata.org/entity/Q285453
# 71   PreferredRank                                      NA
# 70   PreferredRank  http://www.wikidata.org/entity/Q285453
# 102     NormalRank  http://www.wikidata.org/entity/Q285453
#
#                                                 refurl wikidata_id_y
# 326                      https://www.weiach.ch/page/13        Q70088
# 325  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q70088
# 290  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q67957
# 336  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q66752
# 311  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q66678
# 233                                                 NA        Q68286
# 236  https://statistik.zh.ch/internet/justiz_innere...        Q68447
# 237  https://statistik.zh.ch/internet/justiz_innere...        Q68447
# 322  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q67882
# 323  https://statistik.zh.ch/internet/justiz_innere...        Q67882
# 334  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q67223
# 333  https://statistik.zh.ch/internet/justiz_innere...        Q67223
# 269  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q70264
# 294  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q67884
# 123  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q67957
# 92   http://www.neftenbach.ch/de/ueberunsmain/gemei...        Q65040
# 141  https://statistik.zh.ch/internet/justiz_innere...        Q70072
# 140  https://www.bfs.admin.ch/bfs/de/home/statistik...        Q70072
# 49   https://statistik.zh.ch/internet/justiz_innere...        Q66964
# 48   https://www.bfs.admin.ch/bfs/de/home/statistik...        Q66964
# 71   https://statistik.zh.ch/internet/justiz_innere...        Q65671
# 70   https://www.bfs.admin.ch/bfs/de/home/statistik...        Q65671
# 102  https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0...        Q70264

# %%
# check
if duplicate.shape[0] + df_api_sel_t.shape[0] == df_api_wikidata.shape[0]:
    print("check ok")
# Out:
# check ok

# %%
# should be 162
print(len(df_api_wikidata.BFS_NR.unique())) # one is missing

print(len(df_api.BFS_NR.unique())) #too many because of "Gemeindefusion"

print(len(df_api_qnumber_dropna.BFS_NR.unique())) #ok

print(len(df_api_sel_t.BFS_NR.unique())) # one is missing
# Out:
# 161
# 176
# 162
# 161
