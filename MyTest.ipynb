# %%
# !pip install -r requirements.txt

import pandas as pd
import requests
import zipfile
import os
import shutil
from SPARQLWrapper import SPARQLWrapper, JSON, XML
import logging
# Out:
# Requirement already satisfied: SPARQLWrapper==1.8.4 in /srv/paws/lib/python3.6/site-packages (from -r requirements.txt (line 1))
# Requirement already satisfied: rdflib>=4.0 in /srv/paws/lib/python3.6/site-packages (from SPARQLWrapper==1.8.4->-r requirements.txt (line 1))
# Requirement already satisfied: isodate in /srv/paws/lib/python3.6/site-packages (from rdflib>=4.0->SPARQLWrapper==1.8.4->-r requirements.txt (line 1))
# Requirement already satisfied: pyparsing in /srv/paws/lib/python3.6/site-packages (from rdflib>=4.0->SPARQLWrapper==1.8.4->-r requirements.txt (line 1))
# Requirement already satisfied: six in /srv/paws/lib/python3.6/site-packages (from isodate->rdflib>=4.0->SPARQLWrapper==1.8.4->-r requirements.txt (line 1))

# %%
query = """
    SELECT ?bfs_id ?wikidata_id ?date ?population ?qualifier ?refurl ?refpublisher 
        WHERE
        {
            # ?wikidata_id wdt:P771 ?bfs_id.
            # ?wikidata_id wdt:P31 wd:Q70208.
            # ?wikidata_id wdt:P131 wd:Q11943.
            # ?wikidata_id p:P1082 ?myvalue.
            # ?myvalue pq:P585 ?date.
            # ?myvalue ps:P1082 ?population.
            # ?myvalue wikibase:rank ?qualifier.
            # ?myvalue prov:wasDerivedFrom ?refnode.
            OPTIONAL{?refnode pr:P854 ?refurl.}
            OPTIONAL{?refnode pr:P123 ?refpublisher.}
            SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
        }
    order by ?bfs_id ?date
    """

sparql = SPARQLWrapper("https://query.wikidata.org/sparql", agent = "Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36")
sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

result = results['results']['bindings']

result
# Out:
# [{'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64945'},
#   'bfs_id': {'type': 'literal', 'value': '0001'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1934'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=1'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64945'},
#   'bfs_id': {'type': 'literal', 'value': '0001'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1941'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64945'},
#   'bfs_id': {'type': 'literal', 'value': '0001'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1982'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68290'},
#   'bfs_id': {'type': 'literal', 'value': '0002'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '11276'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2012-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'http://www.pxweb.bfs.admin.ch/Dialog/varval.asp?ma=px-d-01-2A00&ti=St%E4ndige+und+nichtst%E4ndige+Wohnbev%F6lkerung+nach+institutionellen+Gliederungen%2C+Geschlecht%2C+Zivilstand+und+Geburtsort&path=../Database/German_01%20-%20Bev%F6lkerung/01.2%20-%20Bev%F6lkerungsstand%20und%20-bewegung/&lang=1&prod=01&openChild=true&secprod=2'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68290'},
#   'bfs_id': {'type': 'literal', 'value': '0002'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '12080'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=2'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68290'},
#   'bfs_id': {'type': 'literal', 'value': '0002'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '12146'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68290'},
#   'bfs_id': {'type': 'literal', 'value': '0002'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '12226'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65510'},
#   'bfs_id': {'type': 'literal', 'value': '0003'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5491'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65510'},
#   'bfs_id': {'type': 'literal', 'value': '0003'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5491'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=3'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65510'},
#   'bfs_id': {'type': 'literal', 'value': '0003'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5512'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65510'},
#   'bfs_id': {'type': 'literal', 'value': '0003'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5543'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65231'},
#   'bfs_id': {'type': 'literal', 'value': '0004'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3376'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2012-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'http://www.pxweb.bfs.admin.ch/Dialog/varval.asp?ma=px-d-01-2A00&ti=St%E4ndige+und+nichtst%E4ndige+Wohnbev%F6lkerung+nach+institutionellen+Gliederungen%2C+Geschlecht%2C+Zivilstand+und+Geburtsort&path=../Database/German_01%20-%20Bev%F6lkerung/01.2%20-%20Bev%F6lkerungsstand%20und%20-bewegung/&lang=1&prod=01&openChild=true&secprod=2'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65231'},
#   'bfs_id': {'type': 'literal', 'value': '0004'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3646'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=4'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65231'},
#   'bfs_id': {'type': 'literal', 'value': '0004'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3646'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65231'},
#   'bfs_id': {'type': 'literal', 'value': '0004'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3664'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65231'},
#   'bfs_id': {'type': 'literal', 'value': '0004'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3701'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65129'},
#   'bfs_id': {'type': 'literal', 'value': '0005'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3678'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65129'},
#   'bfs_id': {'type': 'literal', 'value': '0005'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3678'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=5'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65129'},
#   'bfs_id': {'type': 'literal', 'value': '0005'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3694'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65129'},
#   'bfs_id': {'type': 'literal', 'value': '0005'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3734'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64589'},
#   'bfs_id': {'type': 'literal', 'value': '0006'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '922'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2012-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'http://www.pxweb.bfs.admin.ch/Dialog/varval.asp?ma=px-d-01-2A00&ti=St%E4ndige+und+nichtst%E4ndige+Wohnbev%F6lkerung+nach+institutionellen+Gliederungen%2C+Geschlecht%2C+Zivilstand+und+Geburtsort&path=../Database/German_01%20-%20Bev%F6lkerung/01.2%20-%20Bev%F6lkerungsstand%20und%20-bewegung/&lang=1&prod=01&openChild=true&secprod=2'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64589'},
#   'bfs_id': {'type': 'literal', 'value': '0006'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1124'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64589'},
#   'bfs_id': {'type': 'literal', 'value': '0006'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1124'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=6'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64589'},
#   'bfs_id': {'type': 'literal', 'value': '0006'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1125'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64589'},
#   'bfs_id': {'type': 'literal', 'value': '0006'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1157'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66328'},
#   'bfs_id': {'type': 'literal', 'value': '0007'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2301'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66328'},
#   'bfs_id': {'type': 'literal', 'value': '0007'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2301'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=7'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66328'},
#   'bfs_id': {'type': 'literal', 'value': '0007'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2305'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66328'},
#   'bfs_id': {'type': 'literal', 'value': '0007'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2372'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64977'},
#   'bfs_id': {'type': 'literal', 'value': '0008'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '636'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64977'},
#   'bfs_id': {'type': 'literal', 'value': '0008'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '636'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=8'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64977'},
#   'bfs_id': {'type': 'literal', 'value': '0008'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '641'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64977'},
#   'bfs_id': {'type': 'literal', 'value': '0008'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '656'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65547'},
#   'bfs_id': {'type': 'literal', 'value': '0009'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4865'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65547'},
#   'bfs_id': {'type': 'literal', 'value': '0009'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4865'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=9'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65547'},
#   'bfs_id': {'type': 'literal', 'value': '0009'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4886'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65547'},
#   'bfs_id': {'type': 'literal', 'value': '0009'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5094'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65942'},
#   'bfs_id': {'type': 'literal', 'value': '0010'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5340'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65942'},
#   'bfs_id': {'type': 'literal', 'value': '0010'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5340'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=10'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65942'},
#   'bfs_id': {'type': 'literal', 'value': '0010'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5356'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65942'},
#   'bfs_id': {'type': 'literal', 'value': '0010'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5592'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67513'},
#   'bfs_id': {'type': 'literal', 'value': '0011'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2556'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67513'},
#   'bfs_id': {'type': 'literal', 'value': '0011'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2556'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=11'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67513'},
#   'bfs_id': {'type': 'literal', 'value': '0011'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2569'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67513'},
#   'bfs_id': {'type': 'literal', 'value': '0011'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2555'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66598'},
#   'bfs_id': {'type': 'literal', 'value': '0012'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1096'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66598'},
#   'bfs_id': {'type': 'literal', 'value': '0012'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1096'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=12'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66598'},
#   'bfs_id': {'type': 'literal', 'value': '0012'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1103'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66598'},
#   'bfs_id': {'type': 'literal', 'value': '0012'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1123'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66062'},
#   'bfs_id': {'type': 'literal', 'value': '0013'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3687'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66062'},
#   'bfs_id': {'type': 'literal', 'value': '0013'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3687'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=13'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66062'},
#   'bfs_id': {'type': 'literal', 'value': '0013'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3717'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q66062'},
#   'bfs_id': {'type': 'literal', 'value': '0013'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3679'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65934'},
#   'bfs_id': {'type': 'literal', 'value': '0014'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5097'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65934'},
#   'bfs_id': {'type': 'literal', 'value': '0014'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5097'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=14'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65934'},
#   'bfs_id': {'type': 'literal', 'value': '0014'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5112'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65934'},
#   'bfs_id': {'type': 'literal', 'value': '0014'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5186'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68356'},
#   'bfs_id': {'type': 'literal', 'value': '0021'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '655'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=21'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68356'},
#   'bfs_id': {'type': 'literal', 'value': '0021'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '665'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68356'},
#   'bfs_id': {'type': 'literal', 'value': '0021'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '707'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q70171'},
#   'bfs_id': {'type': 'literal', 'value': '0022'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '857'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q70171'},
#   'bfs_id': {'type': 'literal', 'value': '0022'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '857'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=22'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q70171'},
#   'bfs_id': {'type': 'literal', 'value': '0022'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '858'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q70171'},
#   'bfs_id': {'type': 'literal', 'value': '0022'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '855'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65781'},
#   'bfs_id': {'type': 'literal', 'value': '0023'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '562'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65781'},
#   'bfs_id': {'type': 'literal', 'value': '0023'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '562'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=23'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65781'},
#   'bfs_id': {'type': 'literal', 'value': '0023'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '564'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q65781'},
#   'bfs_id': {'type': 'literal', 'value': '0023'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '570'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68451'},
#   'bfs_id': {'type': 'literal', 'value': '0024'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '970'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68451'},
#   'bfs_id': {'type': 'literal', 'value': '0024'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '970'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=24'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68451'},
#   'bfs_id': {'type': 'literal', 'value': '0024'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '971'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68451'},
#   'bfs_id': {'type': 'literal', 'value': '0024'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '977'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
# ...
#   'bfs_id': {'type': 'literal', 'value': '0261'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '407447'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q72'},
#   'bfs_id': {'type': 'literal', 'value': '0261'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '409241'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q72'},
#   'bfs_id': {'type': 'literal', 'value': '0261'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '410779'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'http://population.city/switzerland/zurich/'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q72'},
#   'bfs_id': {'type': 'literal', 'value': '0261'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '415215'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q60322693'},
#   'bfs_id': {'type': 'literal', 'value': '0292'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2746'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q69718'},
#   'bfs_id': {'type': 'literal', 'value': '0293'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '20967'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2012-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfsstatic/dam/assets/2348672/master'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q69718'},
#   'bfs_id': {'type': 'literal', 'value': '0293'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '21716'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q69718'},
#   'bfs_id': {'type': 'literal', 'value': '0293'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '21792'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q69718'},
#   'bfs_id': {'type': 'literal', 'value': '0293'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '21617'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67137'},
#   'bfs_id': {'type': 'literal', 'value': '0294'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4903'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68286'},
#   'bfs_id': {'type': 'literal', 'value': '0295'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '22476'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68286'},
#   'bfs_id': {'type': 'literal', 'value': '0295'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '22476'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q68286'},
#   'bfs_id': {'type': 'literal', 'value': '0295'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '22662'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64873'},
#   'bfs_id': {'type': 'literal', 'value': '0296'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '16117'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2012-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'http://www.pxweb.bfs.admin.ch/Dialog/varval.asp?ma=px-d-01-2A00&ti=St%E4ndige+und+nichtst%E4ndige+Wohnbev%F6lkerung+nach+institutionellen+Gliederungen%2C+Geschlecht%2C+Zivilstand+und+Geburtsort&path=../Database/German_01%20-%20Bev%F6lkerung/01.2%20-%20Bev%F6lkerungsstand%20und%20-bewegung/&lang=1&prod=01&openChild=true&secprod=2'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64873'},
#   'bfs_id': {'type': 'literal', 'value': '0296'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '16928'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64873'},
#   'bfs_id': {'type': 'literal', 'value': '0296'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '16928'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=296'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64873'},
#   'bfs_id': {'type': 'literal', 'value': '0296'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '16975'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64873'},
#   'bfs_id': {'type': 'literal', 'value': '0296'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '17066'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67145'},
#   'bfs_id': {'type': 'literal', 'value': '0297'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4925'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67145'},
#   'bfs_id': {'type': 'literal', 'value': '0297'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4925'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html?tab=indikatoren&jahr=2017&indikatoren=133&bfs=297'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67145'},
#   'bfs_id': {'type': 'literal', 'value': '0297'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4939'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q67145'},
#   'bfs_id': {'type': 'literal', 'value': '0297'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4965'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64853'},
#   'bfs_id': {'type': 'literal', 'value': '0298'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6355'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-01-01T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://statistik.zh.ch/internet/justiz_inneres/statistik/de/daten/gemeindeportraet_kanton_zuerich.html#a-content'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64853'},
#   'bfs_id': {'type': 'literal', 'value': '0298'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6380'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2017-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#NormalRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.pxweb.bfs.admin.ch/pxweb/de/px-x-0102020000_201'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}},
#  {'wikidata_id': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q64853'},
#   'bfs_id': {'type': 'literal', 'value': '0298'},
#   'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6521'},
#   'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-12-31T00:00:00Z'},
#   'qualifier': {'type': 'uri',
#    'value': 'http://wikiba.se/ontology#PreferredRank'},
#   'refurl': {'type': 'uri',
#    'value': 'https://www.bfs.admin.ch/bfs/de/home/statistiken/bevoelkerung.assetdetail.7966022.html'},
#   'refpublisher': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q285453'}}]

# %%
type(result)
# Out:
# list

# %%
result[]

# %%
population = []
for p in result:
        mon = {
            #'wikidata_id': p['wikidata_id']['value'].replace('http://www.wikidata.org/entity/', ''),
            #'bfs_id' : p['bfs_id']['value'],
            'refurl1' : p['qualifier']['value'],
            'refurl2' : p['refurl']['value'],
            #'date': p['date']['value'],
            #'population': p['population']['value'],
            #'qualifier': p['qualifier']['value'].replace('http://wikiba.se/ontology#', ''),
        }
        
population.append(mon)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-64ee83adf850> in <module>
#       5             #'bfs_id' : p['bfs_id']['value'],
#       6             'refurl1' : p['qualifier']['value'],
# ----> 7             'refurl2' : p['refurl']['value'],
#       8             #'date': p['date']['value'],
#       9             #'population': p['population']['value'],
#
# KeyError: 'refurl'

# %%
population
# Out:
# [{'wikidata_id': 'Q64853',
#   'bfs_id': '0298',
#   'refurl': 'http://wikiba.se/ontology#PreferredRank',
#   'date': '2018-12-31T00:00:00Z',
#   'population': '6521',
#   'qualifier': 'PreferredRank'}]
